# %%
import pandas as pd

# %%
import psycopg2

conn = psycopg2.connect(host="squad5-agrobill.cluster-cvpksv55zfzp.us-east-1.rds.amazonaws.com",
                        database="opf",
                        user="postgres",
                        password="agrobill")

cur = conn.cursor()

# %%
cur.execute("""
SELECT * FROM agro_insights;
""")

# %%
cols = [_.name for _ in cur.description]
rows = cur.fetchall()
df = pd.DataFrame(rows)
df.columns = cols
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 4>()
#       2 rows = cur.fetchall()
#       3 df = pd.DataFrame(rows)
# ----> 4 df.columns = cols
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from sqlalchemy import create_engine

# %%
#df.head(0).to_sql('table_name', engine, if_exists='replace',index=False) #drops old table and creates new empty table

# %%
host = "squad5-agrobill.cluster-cvpksv55zfzp.us-east-1.rds.amazonaws.com"

# %%
engine = create_engine(f'postgresql+psycopg2://postgres:agrobill@{host}:5432/opf')

# %%
import csv
from io import StringIO

# %%
def psql_insert_copy(table, conn, keys, data_iter):
    # gets a DBAPI connection that can provide a cursor
    dbapi_conn = conn.connection
    with dbapi_conn.cursor() as cur:
        s_buf = StringIO()
        writer = csv.writer(s_buf)
        writer.writerows(data_iter)
        s_buf.seek(0)

        columns = ', '.join('"{}"'.format(k) for k in keys)
        if table.schema:
            table_name = '{}.{}'.format(table.schema, table.name)
        else:
            table_name = table.name

        sql = 'COPY {} ({}) FROM STDIN WITH CSV'.format(
            table_name, columns)
        cur.copy_expert(sql=sql, file=s_buf)

# %%
#engine = create_engine('postgresql://myusername:mypassword@myhost:5432/mydatabase')
#df.to_sql('table_name', engine, method=psql_insert_copy)

# %%
df22.to_sql('agro_insights', engine, if_exists='replace', method=psql_insert_copy)

# %%
df22.to_sql('agro_insights', engine, if_exists='replace', index=False)

# %%
df22 = pd.read_pickle('agro_insights.pkl')

# %%
df22
# Out:
#          customerId                            contractId  \
# 0    595.080.896-84  c194d903-fca1-497f-b5f3-0204e426e798
# 1    412.289.303-97  3528e870-9a85-4160-a81f-0aa20359f3c7
# 2    785.797.738-73  e0432420-a9c9-450b-85ed-2753fbdfa4b0
# 3    331.154.515-63  872c89e5-4234-4b0b-a0ae-30cd0f3e3e66
# 4    114.795.138-29  ca78548d-b209-4134-9dd9-fa8eee2e5efd
# ..              ...                                   ...
# 495  504.337.567-56  a753bfd9-1a38-4649-b6b6-e262128063c1
# 496  797.640.888-18  e8a300d2-025d-43dc-b0c3-bf137691aba5
# 497  478.472.740-45  6362005a-ad64-4d57-91b8-97df9664df12
# 498  651.841.821-25  1da402ce-d7a4-44ce-81ff-d625dc77b081
# 499  219.778.534-52  6819adc4-df5a-4fa3-988b-e91bb3e6887d
#
#                            organizationId           organizationName  \
# 0    69665991-da55-4aac-a1f2-32d23daba8fe  Instituição Financeira 03
# 1    69665991-da55-4aac-a1f2-32d23daba8fe  Instituição Financeira 03
# ...

# %%
df22
# Out:
#          customerId                            contractId  \
# 0    595.080.896-84  c194d903-fca1-497f-b5f3-0204e426e798
# 1    412.289.303-97  3528e870-9a85-4160-a81f-0aa20359f3c7
# 2    785.797.738-73  e0432420-a9c9-450b-85ed-2753fbdfa4b0
# 3    331.154.515-63  872c89e5-4234-4b0b-a0ae-30cd0f3e3e66
# 4    114.795.138-29  ca78548d-b209-4134-9dd9-fa8eee2e5efd
# ..              ...                                   ...
# 495  504.337.567-56  a753bfd9-1a38-4649-b6b6-e262128063c1
# 496  797.640.888-18  e8a300d2-025d-43dc-b0c3-bf137691aba5
# 497  478.472.740-45  6362005a-ad64-4d57-91b8-97df9664df12
# 498  651.841.821-25  1da402ce-d7a4-44ce-81ff-d625dc77b081
# 499  219.778.534-52  6819adc4-df5a-4fa3-988b-e91bb3e6887d
#
#                            organizationId           organizationName  \
# 0    69665991-da55-4aac-a1f2-32d23daba8fe  Instituição Financeira 03
# 1    69665991-da55-4aac-a1f2-32d23daba8fe  Instituição Financeira 03
# ...

# %%
cur.execute("""CREATE DATABASE opf;""")
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 cur.execute("""CREATE DATABASE opf;""")
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block

# %%
conn.commit()

# %%
cur.execute("""
CREATE TABLE IF NOT EXISTS agro_insights (
    customerId string,
contractId string,
organizationId string,
organizationName string,
contractNumber string,
productName string,
contractAmount string,
fd_productType string,
fc_productType string,
warrantyType string,
warrantySubType string,
warrantyAmount string,
brandName string,
totalNumberOfInstalments string,
fp_paidInstalments string,
fsi_paidInstalments string,
contractOutstandingBalance string
)
""")
# Out:
# ---------------------------------------------------------------------------
# UndefinedObject                           Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 cur.execute("""
#       2 CREATE TABLE IF NOT EXISTS agro_insights (
#       3     customerId string,
#       4 contractId string,
#       5 organizationId string,
#       6 organizationName string,
#       7 contractNumber string,
#       8 productName string,
#       9 contractAmount string,
#      10 fd_productType string,
#      11 fc_productType string,
#      12 warrantyType string,
#      13 warrantySubType string,
#      14 warrantyAmount string,
#      15 brandName string,
#      16 totalNumberOfInstalments string,
#      17 fp_paidInstalments string,
#      18 fsi_paidInstalments string,
#      19 contractOutstandingBalance string
#      20 )
#      21 """)
#
# UndefinedObject: type "string" does not exist
# LINE 3:     customerId string,
#                        ^

# %%
cur.execute("""
SELECT
    *
FROM
    agro_insights;
""")
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 cur.execute("""
#       2 SELECT
#       3     *
#       4 FROM
#       5     agro_insights;
#       6 """)
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block

# %%
import pandas as pd
cols = [_.name for _ in cur.description]
rows = cur.fetchall()
df = pd.DataFrame(rows)
df.columns = cols
